# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/dell/af/DM

# %%
data_file = r"./0901_DM4ft.csv"

# %%
data = pd.read_csv(data_file)

# %%
data.loc[:,"SMILES"].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 41158    False
# 41159    False
# 41160    False
# 41161    False
# 41162    False
# Name: SMILES, Length: 41163, dtype: bool

# %%
data.iloc[data.index[~data.loc[:,"SMILES"].isna()],:].to_csv(r"./0902_DM4ft.csv", index=False)
